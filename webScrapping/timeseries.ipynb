# %%
import os

directory_path = '/Users/manisarthak/Desktop/CGWB/'

def getYears(path):
    items = os.listdir(directory_path)
    directories = [item for item in items if os.path.isdir(os.path.join(directory_path, item)) and item[0] != '.']
    directories.sort()
    return directories

years = getYears(directory_path)
print(years)

def getStates(year):
    path = directory_path + str(year)+'/'
    items = os.listdir(path)
    directories = [item for item in items if os.path.isdir(os.path.join(path, item)) ]
    directories.sort()
    return directories



states = getStates(years[-1])
print(states)


def getDistricts(state, year):
    path = directory_path + str(year)+'/'+str(state)+'/'
    items = os.listdir(path)
    directories = [item for item in items if os.path.isdir(os.path.join(path, item)) ]
    directories.sort()
    return directories

print(getDistricts('Bihar', 2023))
# Out:
# ['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023']
# ['Andaman & Nicobar', 'Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh', 'Delhi', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Meghalaya', 'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal']
# ['Araria', 'Aurangabad', 'Banka', 'Begusarai', 'Bhagalpur', 'Bhojpur', 'Buxar', 'Darbhanga', 'Gaya', 'Gopalganj', 'Jamui', 'Jehanabad', 'Kaimur', 'Katihar', 'Khagaria', 'Kishanganj', 'Lakhisarai', 'Madhepura', 'Madhubani', 'Munger', 'Muzaffarpur', 'Nalanda', 'Nawada', 'Pashchim Champaran', 'Patna', 'Purba Champaran', 'Purnia', 'Rohtas', 'Saharsa', 'Samastipur', 'Saran', 'Sheikhpura', 'Sheohar', 'Sitamarhi', 'Siwan', 'Supaul', 'Vaishali']

# %%
import os

# Specify the path to the directory you want to list
directory_path = "/Users/manisarthak/Desktop/CGWB/2023/"

# List all items (files and directories) in the specified directory
items = os.listdir(directory_path)

# Filter the list to include only directories
directories = [item for item in items if os.path.isdir(os.path.join(directory_path, item))]

print(directories)
# Out:
# ['Andaman & Nicobar', 'Arunachal Pradesh', 'Andhra Pradesh', 'Telangana', 'Madhya Pradesh', 'Haryana', 'Gujarat', 'Himachal Pradesh', 'Delhi', 'Goa', 'Punjab', 'Jammu & Kashmir', 'Karnataka', 'Maharashtra', 'Odisha', 'Rajasthan', 'Chandigarh', 'Kerala', 'Chhattisgarh', 'Tripura', 'Assam', 'Meghalaya', 'Tamil Nadu', 'West Bengal', 'Uttarakhand', 'Uttar Pradesh', 'Puducherry', 'Bihar', 'Jharkhand', 'Nagaland']

# %%
from yearly import *


# states = getStates(2023)
# print(states)


states = ['Bihar']
for state in states:
    print(state)
    # districts = getDistricts(state, 2023)
    # print(districts)
    
    districts = ['Saran']
    
    
    for district in districts:
        for year in years:
            path = directory_path + f"{year}/{state}/{district}/"
            print(path)
# Out:
# ['Andaman & Nicobar', 'Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Meghalaya', 'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttarakhand', 'Uttar Pradesh', 'West Bengal']
# Bihar
# ['Aurangabad', 'Banka', 'Bhojpur', 'Buxar', 'Gaya', 'Gopalganj', 'Jamui', 'Jehanabad', 'Kaimur', 'Lakhisarai', 'Munger', 'Muzaffarpur', 'Nalanda', 'Nawada', 'Pashchim Champaran', 'Patna', 'Purba Champaran', 'Rohtas', 'Saran', 'Sheikhpura', 'Siwan', 'Vaishali']
# /Users/manisarthak/Desktop/CGWB/2008/Bihar/Saran/
# /Users/manisarthak/Desktop/CGWB/2009/Bihar/Saran/
# /Users/manisarthak/Desktop/CGWB/2010/Bihar/Saran/
# /Users/manisarthak/Desktop/CGWB/2011/Bihar/Saran/
# /Users/manisarthak/Desktop/CGWB/2012/Bihar/Saran/
# /Users/manisarthak/Desktop/CGWB/2013/Bihar/Saran/
# ...

# %%
import os

# Specify the directory path
path = '/Users/manisarthak/Desktop/CGWB/2008/Bihar/Saran/'

# List all files in the directory
files = os.listdir(path)

# Filter Excel files by extension (assuming they have a .xlsx extension)
excel_files = [file for file in files if file.endswith('.xlsx')]
excel_files.sort()
print(excel_files)

for i in range(1, 5):
    file_path = path + excel_files[i-1]
    print(file_path)
    df = pd.read_excel(file_path, header=None)
    print(df)
    break
# Out:
# ['Saran_Bihar_2008_1.xlsx', 'Saran_Bihar_2008_2.xlsx', 'Saran_Bihar_2008_3.xlsx', 'Saran_Bihar_2008_4.xlsx', 'Saran_Bihar_2008_yearly.xlsx']
# /Users/manisarthak/Desktop/CGWB/2008/Bihar/Saran/Saran_Bihar_2008_1.xlsx
#               0                1                   2          3          4
# 0  station_name       station_id  water_level (in m)        lat       long
# 1          Ammi  254430084574501                 6.6  25.741667    84.9625
# 2       Chhapra  254645084423001                3.75  25.779167  84.708333
# 3      Jalalpur  255845084410001                 2.7  25.979167  84.683333
# 4        Manjhi  255000084344501                 5.1  25.833333  84.579167
# 5         Nagra  254933084434001                 3.9  25.825833  84.727778
# 6      Nayagaon  254545085051501                 6.4    25.7625    85.0875
# 7      Sonepur1  254201085104601                0.72  25.700278  85.179444

# %%
scam1 = getStationsInDistrict('Bihar', 'Saran', 2008, 1)
scam2 = addLatLong(scam1)

# %%
print(scam1)
print(scam2)
# Out:
# [['Ammi', '254430084574501', 6.6], ['Chhapra', '254645084423001', 3.75], ['Jalalpur', '255845084410001', 2.7], ['Manjhi', '255000084344501', 5.1], ['Nagra', '254933084434001', 3.9], ['Nayagaon', '254545085051501', 6.4], ['Sonepur1', '254201085104601', 0.72]]
# [['Ammi', '254430084574501', 6.6, 25.74166667, 84.9625], ['Chhapra', '254645084423001', 3.75, 25.77916667, 84.70833333], ['Jalalpur', '255845084410001', 2.7, 25.97916667, 84.68333333], ['Manjhi', '255000084344501', 5.1, 25.83333333, 84.57916667], ['Nagra', '254933084434001', 3.9, 25.82583333, 84.72777778], ['Nayagaon', '254545085051501', 6.4, 25.7625, 85.0875], ['Sonepur1', '254201085104601', 0.72, 25.70027778, 85.17944444]]

# %%
print(df)
# Out:
#               0                1                   2          3          4
# 0  station_name       station_id  water_level (in m)        lat       long
# 1          Ammi  254430084574501                 6.6  25.741667    84.9625
# 2       Chhapra  254645084423001                3.75  25.779167  84.708333
# 3      Jalalpur  255845084410001                 2.7  25.979167  84.683333
# 4        Manjhi  255000084344501                 5.1  25.833333  84.579167
# 5         Nagra  254933084434001                 3.9  25.825833  84.727778
# 6      Nayagaon  254545085051501                 6.4    25.7625    85.0875
# 7      Sonepur1  254201085104601                0.72  25.700278  85.179444

# %%
scam = df.values.tolist()
print(scam[1:] == scam2)
# Out:
# True

# %%
def readFromExcel(state, district, year, season, directory_path = "/Users/manisarthak/Desktop/CGWB/"):
    excel_path = directory_path + f"{year}/{state}/{district}/{district}_{state}_{year}_{season}.xlsx"
    scam = []
    try:
        df = pd.read_excel(excel_path, header=None)
        scam = df.values.tolist()[1:]
    except Exception as e:
        print("Error --- \n", year, state, district, season)
        print(e)
    return scam

print(readFromExcel('Rajasthan', 'Bhilwara', 2007, 3))
# Out:
# Error ---
#  2007 Rajasthan Bhilwara 3
# [Errno 2] No such file or directory: '/Users/manisarthak/Desktop/CGWB/2007/Rajasthan/Bhilwara/Bhilwara_Rajasthan_2007_3.xlsx'
# ['0']

# %%
from createTimeSeries import getYearlyDataForDistricts, mergeThroughYears, modifyDataForCSV, writeInCSV




data = getYearlyDataForDistricts(2008, 'Bihar', 'Saran')
data = mergeThroughYears('Bihar', 'Saran', 2008, 2023)
data = modifyDataForCSV(data)
writeInCSV(data, "temp.csv")


for k in data:
    print(k, data[k])
# Out:
# 2008 Bihar Saran 1 done
# 2008 Bihar Saran 2 done
# 2008 Bihar Saran 3 done
# 2008 Bihar Saran 4 done
# 2008 Bihar Saran done
#
#
# 2008 Bihar Saran 1 done
# 2008 Bihar Saran 2 done
# 2008 Bihar Saran 3 done
# 2008 Bihar Saran 4 done
# 2008 Bihar Saran done
#
#
# 2009 Bihar Saran 1 done
# 2009 Bihar Saran 2 done
# 2009 Bihar Saran 3 done
# 2009 Bihar Saran 4 done
# 2009 Bihar Saran done
#
#
# 2010 Bihar Saran 1 done
# 2010 Bihar Saran 2 done
# 2010 Bihar Saran 3 done
# 2010 Bihar Saran 4 done
# 2010 Bihar Saran done
#
#
# 2011 Bihar Saran 1 done
# 2011 Bihar Saran 2 done
# 2011 Bihar Saran 3 done
# 2011 Bihar Saran 4 done
# 2011 Bihar Saran done
#
#
# 2012 Bihar Saran 1 done
# 2012 Bihar Saran 2 done
# 2012 Bihar Saran 3 done
# 2012 Bihar Saran 4 done
# 2012 Bihar Saran done
#
#
# 2013 Bihar Saran 1 done
# 2013 Bihar Saran 2 done
# 2013 Bihar Saran 3 done
# 2013 Bihar Saran 4 done
# 2013 Bihar Saran done
#
#
# 2014 Bihar Saran 1 done
# 2014 Bihar Saran 2 done
# ...

# %%
year = 2023
print(states)
for state in states:
    os.makedirs(directory_path+f"/timeSeries/{state}", exist_ok=True)
    print(f"starting state: {state}")
    districts = getDistricts(state, year)
    print(districts)
    for district in districts:
        print(state, district)
        data = mergeThroughYears(state, district, int(years[0]), int(years[-1]))
        data = modifyDataForCSV(data)
        writeInCSV(data, f"/Users/manisarthak/Desktop/CGWB/timeSeries/{state}/{district}.csv")
        # break
    # break
# Out:
# ['Andaman & Nicobar', 'Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh', 'Delhi', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Meghalaya', 'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal']
# starting state: Andaman & Nicobar
# ['North Middle Andaman', 'South Andaman']
# Andaman & Nicobar North Middle Andaman
# 2008 Andaman & Nicobar North Middle Andaman 1 done
# 2008 Andaman & Nicobar North Middle Andaman 2 done
# 2008 Andaman & Nicobar North Middle Andaman 3 done
# 2008 Andaman & Nicobar North Middle Andaman 4 done
# 2008 Andaman & Nicobar North Middle Andaman done
#
#
# 2009 Andaman & Nicobar North Middle Andaman 1 done
# 2009 Andaman & Nicobar North Middle Andaman 2 done
# 2009 Andaman & Nicobar North Middle Andaman 3 done
# ...
